# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('app/data_local/IQVIA/IQVIA_OneKey_Affiliations.csv')

# print(df) 
# print(pd.options.display.max_rows) 
# print(df.head(10))
# print(df.tail())
print(df.info())

print("Transforming data...")
df['processed_by'] = 'my_first_pipeline'

print(df.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   onekey_hcp_id       120 non-null    str
#  1   npi                 120 non-null    float64
#  2   onekey_hco_id       120 non-null    str
#  3   hco_name            120 non-null    str
#  4   affiliation_type    120 non-null    str
#  5   affiliation_status  120 non-null    str
# dtypes: float64(1), str(5)
# memory usage: 47.0 KB
# None
# Transforming data...
#   onekey_hcp_id           npi onekey_hco_id                       hco_name  \
# 0       HCP0001  1.000000e+09       RUPL004          South End Dermatology
# 1       HCP0002  1.000000e+09       RUPL005  Fenway Dermatology Associates
# 2       HCP0003  1.000000e+09       RUPL002            Seaport Dermatology
# 3       HCP0004  1.000000e+09       CLN0007            Medford Dermatology
# ...

# %%
DATABASE_URL='postgresql+psycopg2://postgres:admin@localhost:5432/kernel_backend_db'
print("Connecting to database and loading data...")
engine = create_engine(DATABASE_URL)

df.to_sql('toy_pipeline_results', engine, if_exists='replace', index=False)
# Out:
# Connecting to database and loading data...
# 999
